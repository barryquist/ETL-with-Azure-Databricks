# %%
# load dataset from Mounted Blob Storage

df = spark.read.format("csv")\
    .option("inferSchema", True) \
    .option("header", True) \
    .option("sep", ",") \
    .load("/mnt/TestMountBlobPython/sales_data.csv")

df.show(10)
# Out:
# +---+--------+--------------------+----------------+----------+-------------------+--------------------+-----+------+--------------+----+
# |_c0|Order ID|             Product|Quantity Ordered|Price Each|         Order Date|    Purchase Address|Month| Sales|          City|Hour|
# +---+--------+--------------------+----------------+----------+-------------------+--------------------+-----+------+--------------+----+
# |  0|  295665|  Macbook Pro Laptop|               1|    1700.0|2019-12-30 00:01:00|136 Church St, Ne...|   12|1700.0| New York City|   0|
# |  1|  295666|  LG Washing Machine|               1|     600.0|2019-12-29 07:03:00|562 2nd St, New Y...|   12| 600.0| New York City|   7|
# |  2|  295667|USB-C Charging Cable|               1|     11.95|2019-12-12 18:21:00|277 Main St, New ...|   12| 11.95| New York City|  18|
# |  3|  295668|    27in FHD Monitor|               1|    149.99|2019-12-22 15:13:00|410 6th St, San F...|   12|149.99| San Francisco|  15|
# |  4|  295669|USB-C Charging Cable|               1|     11.95|2019-12-18 12:38:00|43 Hill St, Atlan...|   12| 11.95|       Atlanta|  12|
# |  5|  295670|AA Batteries (4-p...|               1|      3.84|2019-12-31 22:58:00|200 Jefferson St,...|   12|  3.84| New York City|  22|
# |  6|  295671|USB-C Charging Cable|               1|     11.95|2019-12-16 15:10:00|928 12th St, Port...|   12| 11.95|      Portland|  15|
# |  7|  295672|USB-C Charging Cable|               2|     11.95|2019-12-13 09:29:00|813 Hickory St, D...|   12|  23.9|        Dallas|   9|
# |  8|  295673|Bose SoundSport H...|               1|     99.99|2019-12-15 23:26:00|718 Wilson St, Da...|   12| 99.99|        Dallas|  23|
# |  9|  295674|AAA Batteries (4-...|               4|      2.99|2019-12-28 11:51:00|77 7th St, Dallas...|   12| 11.96|        Dallas|  11|
# +---+--------+--------------------+----------------+----------+-------------------+--------------------+-----+------+--------------+----+
# only showing top 10 rows

# %%
df.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- Order ID: integer (nullable = true)
#  |-- Product: string (nullable = true)
#  |-- Quantity Ordered: integer (nullable = true)
#  |-- Price Each: double (nullable = true)
#  |-- Order Date: timestamp (nullable = true)
#  |-- Purchase Address: string (nullable = true)
#  |-- Month: integer (nullable = true)
#  |-- Sales: double (nullable = true)
#  |-- City: string (nullable = true)
#  |-- Hour: integer (nullable = true)

# %%
# Get size of dataframe

print("{} rows".format(df.count()))
print("{} columns".format(len(df.columns)))
# Out:
# 185950 rows
# 11 columns

# %%
# Rename columns

df = df.withColumnRenamed("Quantity Ordered", "Quantity_Ordered")
df = df.withColumnRenamed("Price Each", "Price")
df = df.withColumnRenamed('Order Date', 'Order_date')
df = df.withColumnRenamed('Purchase Address', 'Purchase_address')
df = df.withColumnRenamed('Order ID', 'Order_ID')

df.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- Order_ID: integer (nullable = true)
#  |-- Product: string (nullable = true)
#  |-- Quantity_Ordered: integer (nullable = true)
#  |-- Price: double (nullable = true)
#  |-- Order_date: timestamp (nullable = true)
#  |-- Purchase_address: string (nullable = true)
#  |-- Month: integer (nullable = true)
#  |-- Sales: double (nullable = true)
#  |-- City: string (nullable = true)
#  |-- Hour: integer (nullable = true)

# %%
# Drop Duplicates

df.dropDuplicates(['Order_ID'])
# Out:
# Out[6]: DataFrame[_c0: int, Order_ID: int, Product: string, Quantity_Ordered: int, Price: double, Order_date: timestamp, Purchase_address: string, Month: int, Sales: double, City: string, Hour: int]

# %%
# Chnage values in month column to reflect actual month names

from pyspark.sql.functions import col, when

df = df.withColumn(
    "Monthnew",
    when(col("Month") == 12, "Dec")
    .when(col("Month") == 11, "Nov")
    .when(col("Month") == 10, "Oct")
    .when(col("Month") == 9, "Sep")
    .when(col("Month") == 8, "Aug")
    .when(col("Month") == 7, "Jul")
    .when(col("Month") == 6, "Jun")
    .when(col("Month") == 5, "May")
    .when(col("Month") == 4, "Apr")
    .when(col("Month") == 3, "Mar")
    .when(col("Month") == 2, "Feb")
    .when(col("Month") == 1, "Jan"),
)

df.show(10)
# Out:
# +---+--------+--------------------+----------------+------+-------------------+--------------------+-----+------+--------------+----+--------+
# |_c0|Order_ID|             Product|Quantity_Ordered| Price|         Order_date|    Purchase_address|Month| Sales|          City|Hour|Monthnew|
# +---+--------+--------------------+----------------+------+-------------------+--------------------+-----+------+--------------+----+--------+
# |  0|  295665|  Macbook Pro Laptop|               1|1700.0|2019-12-30 00:01:00|136 Church St, Ne...|   12|1700.0| New York City|   0|     Dec|
# |  1|  295666|  LG Washing Machine|               1| 600.0|2019-12-29 07:03:00|562 2nd St, New Y...|   12| 600.0| New York City|   7|     Dec|
# |  2|  295667|USB-C Charging Cable|               1| 11.95|2019-12-12 18:21:00|277 Main St, New ...|   12| 11.95| New York City|  18|     Dec|
# |  3|  295668|    27in FHD Monitor|               1|149.99|2019-12-22 15:13:00|410 6th St, San F...|   12|149.99| San Francisco|  15|     Dec|
# |  4|  295669|USB-C Charging Cable|               1| 11.95|2019-12-18 12:38:00|43 Hill St, Atlan...|   12| 11.95|       Atlanta|  12|     Dec|
# |  5|  295670|AA Batteries (4-p...|               1|  3.84|2019-12-31 22:58:00|200 Jefferson St,...|   12|  3.84| New York City|  22|     Dec|
# |  6|  295671|USB-C Charging Cable|               1| 11.95|2019-12-16 15:10:00|928 12th St, Port...|   12| 11.95|      Portland|  15|     Dec|
# |  7|  295672|USB-C Charging Cable|               2| 11.95|2019-12-13 09:29:00|813 Hickory St, D...|   12|  23.9|        Dallas|   9|     Dec|
# |  8|  295673|Bose SoundSport H...|               1| 99.99|2019-12-15 23:26:00|718 Wilson St, Da...|   12| 99.99|        Dallas|  23|     Dec|
# |  9|  295674|AAA Batteries (4-...|               4|  2.99|2019-12-28 11:51:00|77 7th St, Dallas...|   12| 11.96|        Dallas|  11|     Dec|
# +---+--------+--------------------+----------------+------+-------------------+--------------------+-----+------+--------------+----+--------+
# only showing top 10 rows

# %%
# drop unnecessary columns

df = df.drop('_c0','Order_ID','Month')

df.printSchema()
# Out:
# root
#  |-- Product: string (nullable = true)
#  |-- Quantity_Ordered: integer (nullable = true)
#  |-- Price: double (nullable = true)
#  |-- Order_date: timestamp (nullable = true)
#  |-- Purchase_address: string (nullable = true)
#  |-- Sales: double (nullable = true)
#  |-- City: string (nullable = true)
#  |-- Hour: integer (nullable = true)
#  |-- Monthnew: string (nullable = true)

# %%
# Rename 'Monthnew' column

df = df.withColumnRenamed("Monthnew", "Month")

df.printSchema()
# Out:
# root
#  |-- Product: string (nullable = true)
#  |-- Quantity_Ordered: integer (nullable = true)
#  |-- Price: double (nullable = true)
#  |-- Order_date: timestamp (nullable = true)
#  |-- Purchase_address: string (nullable = true)
#  |-- Sales: double (nullable = true)
#  |-- City: string (nullable = true)
#  |-- Hour: integer (nullable = true)
#  |-- Month: string (nullable = true)

# %%
df.summary().show()
# Out:
# +-------+------------+-------------------+------------------+--------------------+------------------+--------+------------------+------+
# |summary|     Product|   Quantity_Ordered|             Price|    Purchase_address|             Sales|    City|              Hour| Month|
# +-------+------------+-------------------+------------------+--------------------+------------------+--------+------------------+------+
# |  count|      185950|             185950|            185950|              185950|            185950|  185950|            185950|185950|
# |   mean|        null| 1.1243828986286637|184.39973476746866|                null|185.49091675187515|    null|14.413304651788115|  null|
# | stddev|        null|0.44279262402867087|332.73132988434406|                null| 332.9197713864784|    null| 5.423415962073379|  null|
# |    min|20in Monitor|                  1|              2.99|1 11th St, Atlant...|              2.99| Atlanta|                 0|   Apr|
# |    25%|        null|                  1|             11.95|                null|             11.95|    null|                11|  null|
# |    50%|        null|                  1|             14.95|                null|             14.95|    null|                15|  null|
# |    75%|        null|                  1|             150.0|                null|             150.0|    null|                19|  null|
# |    max|      iPhone|                  9|            1700.0|999 Wilson St, Sa...|            3400.0| Seattle|                23|   Sep|
# +-------+------------+-------------------+------------------+--------------------+------------------+--------+------------------+------+

# %%
# Create a view or table

temp_table_name = 'Sales_csv'

df.createOrReplaceTempView(temp_table_name)

# %%
# %sql

SELECT Product, sum(Sales) as Total_Sales 
FROM Sales_csv
GROUP BY Product
ORDER BY Total_Sales desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Product</th><th>Total_Sales</th></tr></thead><tbody><tr><td>Macbook Pro Laptop</td><td>8037600.0</td></tr><tr><td>iPhone</td><td>4794300.0</td></tr><tr><td>ThinkPad Laptop</td><td>4129958.699999968</td></tr><tr><td>Google Phone</td><td>3319200.0</td></tr><tr><td>27in 4K Gaming Monitor</td><td>2435097.5599999577</td></tr><tr><td>34in Ultrawide Monitor</td><td>2355558.0099999583</td></tr><tr><td>Apple Airpods Headphones</td><td>2349150.0</td></tr><tr><td>Flatscreen TV</td><td>1445700.0</td></tr><tr><td>Bose SoundSport Headphones</td><td>1345565.4299999361</td></tr><tr><td>27in FHD Monitor</td><td>1132424.49999997</td></tr><tr><td>Vareebadd Phone</td><td>827200.0</td></tr><tr><td>20in Monitor</td><td>454148.7100000072</td></tr><tr><td>LG Washing Machine</td><td>399600.0</td></tr><tr><td>LG Dryer</td><td>387600.0</td></tr><tr><td>Lightning Charging Cable</td><td>347094.14999996586</td></tr><tr><td>USB-C Charging Cable</td><td>286501.2499999718</td></tr><tr><td>Wired Headphones</td><td>246478.43000000165</td></tr><tr><td>AA Batteries (4-pack)</td><td>106118.40000000344</td></tr><tr><td>AAA Batteries (4-pack)</td><td>92740.83000000483</td></tr></tbody></table></div>

# %%
display(_sqldf)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Product</th><th>Total_Sales</th></tr></thead><tbody><tr><td>Macbook Pro Laptop</td><td>8037600.0</td></tr><tr><td>iPhone</td><td>4794300.0</td></tr><tr><td>ThinkPad Laptop</td><td>4129958.699999968</td></tr><tr><td>Google Phone</td><td>3319200.0</td></tr><tr><td>27in 4K Gaming Monitor</td><td>2435097.5599999577</td></tr><tr><td>34in Ultrawide Monitor</td><td>2355558.0099999583</td></tr><tr><td>Apple Airpods Headphones</td><td>2349150.0</td></tr><tr><td>Flatscreen TV</td><td>1445700.0</td></tr><tr><td>Bose SoundSport Headphones</td><td>1345565.4299999361</td></tr><tr><td>27in FHD Monitor</td><td>1132424.49999997</td></tr><tr><td>Vareebadd Phone</td><td>827200.0</td></tr><tr><td>20in Monitor</td><td>454148.7100000072</td></tr><tr><td>LG Washing Machine</td><td>399600.0</td></tr><tr><td>LG Dryer</td><td>387600.0</td></tr><tr><td>Lightning Charging Cable</td><td>347094.14999996586</td></tr><tr><td>USB-C Charging Cable</td><td>286501.2499999718</td></tr><tr><td>Wired Headphones</td><td>246478.43000000165</td></tr><tr><td>AA Batteries (4-pack)</td><td>106118.40000000344</td></tr><tr><td>AAA Batteries (4-pack)</td><td>92740.83000000483</td></tr></tbody></table></div>

# %%
# With this registered as a temp view, it will only be available to this particular notebook. If you'd like other users to be able to query this table, you can also create a table from the DataFrame.
# Once saved, this table will persist across cluster restarts as well as allow various users across different notebooks to query this data.
# To do so, choose your table name and uncomment the bottom line.

permanent_table_name = "Sales_csv"

df.write.format("parquet").saveAsTable(permanent_table_name)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <command-4089082212914089> in <cell line: 7>()
#       5 permanent_table_name = "Sales_csv"
#       6
# ----> 7 df.write.format("parquet").saveAsTable(permanent_table_name)
#
# /databricks/spark/python/pyspark/instrumentation_utils.py in wrapper(*args, **kwargs)
#      46             start = time.perf_counter()
#      47             try:
# ---> 48                 res = func(*args, **kwargs)
#      49                 logger.log_success(
#      50                     module_name, class_name, function_name, time.perf_counter() - start, signature
#
# /databricks/spark/python/pyspark/sql/readwriter.py in saveAsTable(self, name, format, mode, partitionBy, **options)
#    1039         if format is not None:
#    1040             self.format(format)
# -> 1041         self._jwrite.saveAsTable(name)
#    1042
#    1043     def json(
#
# /databricks/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1319
#    1320         answer = self.gateway_client.send_command(command)
# -> 1321         return_value = get_return_value(
#    1322             answer, self.gateway_client, self.target_id, self.name)
#    1323
#
# /databricks/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#     200                 # Hide where the exception came from that shows a non-Pythonic
#     201                 # JVM exception message.
# --> 202                 raise converted from None
#     203             else:
#     204                 raise
#
# AnalysisException: Table `spark_catalog`.`default`.`sales_csv` already exists.

# %%
# write output to datalake Gen2 Mount Point

_sqldf.write.format("com.databricks.spark.csv").option("header","true").option("delimiter",",").mode("overwrite").save("/mnt/TestMountBlobPython/Sales_data")
